# %% [markdown]
# <h1>End-to-End NLP (EDA & ML) with Sentiment Analysis</h1>

# %% [markdown]
# Source: https://www.kaggle.com/sammir/end-to-end-nlp-eda-ml-with-sentiment-analysis
#
# In this notebook we are going to go through on how to perform text classification using logistic regression and several text encoding techniques such as bag of words and tf-idf. Our task will be to classify text to determine it's sentiment class. Our dataset contains the movie review data with labeled sentiment class of 0,1,2,3 and 4 where 0 is negative, 1 somehow negative, 2 neutral, 3 somehow positive and 4 positive.<br><br>
# We will start with Exploratory Data Analysis then perform machine learning modeling.

# %% [markdown]
# <div align='center'><h1>Import required libraries</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk import ngrams
import string,re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import warnings,os
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mosab\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mosab\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
plt.figure(figsize=(16,7))
plt.style.use('ggplot')
warnings.filterwarnings('ignore')

# %% [markdown]
# Load data

# %%
# Locate the data directories
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train=pd.read_csv('./train.tsv.zip',sep='\t')
test=pd.read_csv('./test.tsv.zip',sep='\t')

# %% [markdown]
# <div align='center'><H1>Part 1 Exploratory Data Analysis</H1></div>

# %%
train.shape, test.shape
# Out:
# ((156060, 4), (66292, 3))

# %%
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
test.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156062        8545  An intermittently pleasing but mostly routine ...
# 2    156063        8545                                                 An
# 3    156064        8545  intermittently pleasing but mostly routine effort
# 4    156065        8545         intermittently pleasing but mostly routine

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PhraseId    156060 non-null  int64
#  1   SentenceId  156060 non-null  int64
#  2   Phrase      156060 non-null  object
#  3   Sentiment   156060 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB

# %%
train.isnull().sum()
# Out:
# PhraseId      0
# SentenceId    0
# Phrase        0
# Sentiment     0
# dtype: int64

# %%
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# Sentiment Description

# %%
train['Sentiment'].value_counts()
# Out:
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: Sentiment, dtype: int64

# %%
train['sentiment_class'].value_counts()
# Out:
# neutral              79582
# somewhat positive    32927
# somewhat negative    27273
# positive              9206
# negative              7072
# Name: sentiment_class, dtype: int64

# %%
train['sentiment_class'] = train['Sentiment'].map({0:'negative',1:'somewhat negative',2:'neutral',3:'somewhat positive',4:'positive'})
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment    sentiment_class
# 0          1  somewhat negative
# 1          2            neutral
# 2          2            neutral
# 3          2            neutral
# 4          2            neutral

# %% [markdown]
# Remove punctuations

# %%
def remove_punctuation(text):
    return "".join([t for t in text if t not in string.punctuation])

# %%
train['Phrase']=train['Phrase'].apply(lambda x:remove_punctuation(x))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment    sentiment_class
# 0          1  somewhat negative
# 1          2            neutral
# 2          2            neutral
# 3          2            neutral
# 4          2            neutral

# %% [markdown]
# Remove words with less than 2 characters

# %%
def words_with_more_than_three_chars(text):
    return " ".join([t for t in text.split() if len(t)>3])

# %%
train['Phrase']=train['Phrase'].apply(lambda x:words_with_more_than_three_chars(x))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage that what...
# 1         2           1  series escapades demonstrating adage that what...
# 2         3           1                                             series
# 3         4           1
# 4         5           1                                             series
#
#    Sentiment    sentiment_class
# 0          1  somewhat negative
# 1          2            neutral
# 2          2            neutral
# 3          2            neutral
# 4          2            neutral

# %% [markdown]
# Remove stopwords

# %%
stop_words=stopwords.words('english')
train['Phrase']=train['Phrase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage good goos...
# 1         2           1    series escapades demonstrating adage good goose
# 2         3           1                                             series
# 3         4           1
# 4         5           1                                             series
#
#    Sentiment    sentiment_class
# 0          1  somewhat negative
# 1          2            neutral
# 2          2            neutral
# 3          2            neutral
# 4          2            neutral

# %% [markdown]
# check sentiment categories

# %%
train.groupby('Sentiment')['Sentiment'].count()
# Out:
# Sentiment
# 0     7072
# 1    27273
# 2    79582
# 3    32927
# 4     9206
# Name: Sentiment, dtype: int64

# %% [markdown]
# Visualize the target variables

# %%
train.groupby('sentiment_class')['sentiment_class'].count().plot(kind='bar',title='Target class',figsize=(16,7),grid=True)
# Out:
# <AxesSubplot:title={'center':'Target class'}, xlabel='sentiment_class'>

# %% [markdown]
# Get percentages of each class

# %%
((train.groupby('sentiment_class')['sentiment_class'].count()/train.shape[0])*100).plot(kind='pie',figsize=(7,7),title='% Target class', autopct='%1.0f%%')
# Out:
# <AxesSubplot:title={'center':'% Target class'}, ylabel='sentiment_class'>

# %% [markdown]
# Adding Phrase length

# %%
train['PhraseLength']=train['Phrase'].apply(lambda x: len(x))

# %%
train.sort_values(by='PhraseLength', ascending=False).head()
# Out:
#        PhraseId  SentenceId  \
# 54876     54877        2734
# 62992     62993        3189
# 26148     26149        1199
# 62500     62501        3162
# 72577     72578        3708
#
#                                                   Phrase  Sentiment  \
# 54876  Filmmakers Dana JanklowiczMann Amir Mann area ...          3
# 62992  addition sporting worst titles recent cinemati...          0
# 26148  movie biggest shocks come seeing former nymphe...          1
# 62500  While transgressive trappings especially frank...          1
# 72577  Stephen Earnhart documentary decomposition hea...          1
#
#          sentiment_class  PhraseLength
# 54876  somewhat positive           207
# 62992           negative           200
# 26148  somewhat negative           199
# 62500  somewhat negative           197
# 72577  somewhat negative           196

# %% [markdown]
# Distribution of phrase length on each class

# %%
plt.figure(figsize=(16,7))
bins=np.linspace(0,200,50)
plt.hist(train[train['sentiment_class']=='negative']['PhraseLength'],bins=bins,density=True,label='negative')
plt.hist(train[train['sentiment_class']=='somewhat negative']['PhraseLength'],bins=bins,density=True,label='somewhat negative')
plt.hist(train[train['sentiment_class']=='neutral']['PhraseLength'],bins=bins,density=True,label='neutral')
plt.hist(train[train['sentiment_class']=='somewhat positive']['PhraseLength'],bins=bins,density=True,label='somewhat positive')
plt.hist(train[train['sentiment_class']=='positive']['PhraseLength'],bins=bins,density=True,label='positive')
plt.xlabel('Phrase length')
plt.legend()
plt.show()

# %% [markdown]
# Common words with word cloud

# %%
# Install wordcoud library
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS 
stopwords = set(STOPWORDS)

# %%
word_cloud_common_words=[]  
for index, row in train.iterrows(): 
    word_cloud_common_words.append((row['Phrase'])) 
word_cloud_common_words

wordcloud = WordCloud(width = 1600, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 5).generate(''.join(word_cloud_common_words)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (16, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
word_cloud_common_words
# Out:
# ['series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story',
#  'series escapades demonstrating adage good goose',
#  'series',
#  '',
#  'series',
#  'escapades demonstrating adage good goose',
#  '',
#  'escapades demonstrating adage good goose',
#  'escapades',
#  'demonstrating adage good goose',
#  'demonstrating adage',
#  'demonstrating',
#  'adage',
#  '',
#  'adage',
#  'good goose',
#  '',
#  'good goose',
#  '',
#  'good goose',
#  '',
#  'good goose',
#  'good',
#  'goose',
#  '',
#  'goose',
#  'goose',
#  'also good gander occasionally amuses none amounts much story',
#  'also good gander occasionally amuses none amounts much story',
#  'also',
#  'also',
#  'good gander occasionally amuses none amounts much story',
#  'gander occasionally amuses none amounts much story',
#  'gander occasionally amuses none amounts much story',
#  'gander',
#  'gander',
#  'gander',
#  '',
#  'occasionally amuses none amounts much story',
#  '',
#  '',
#  '',
#  '',
#  'occasionally amuses none amounts much story',
#  'occasionally',
#  'amuses none amounts much story',
#  'amuses',
#  'none amounts much story',
#  '',
#  'none amounts much story',
#  'none',
#  'amounts much story',
#  'amounts much story',
#  'amounts much story',
#  'amounts',
#  'much story',
#  '',
#  'much story',
#  'much',
#  'story',
#  'story',
#  'story',
#  '',
#  'This quiet introspective entertaining independent worth seeking',
#  'This quiet introspective entertaining independent',
#  'This',
#  'quiet introspective entertaining independent',
#  'quiet introspective entertaining',
#  'quiet',
#  'introspective entertaining',
#  'introspective entertaining',
#  'introspective',
#  'introspective',
#  '',
#  'entertaining',
#  'independent',
#  'worth seeking',
#  'worth seeking',
#  'worth',
#  'worth',
#  'seeking',
#  'Even fans Ismail Merchant work suspect would hard time sitting',
#  'Even fans Ismail Merchant work',
#  'Even fans',
#  'Even',
#  'fans',
#  'Ismail Merchant work',
#  'Ismail Merchant work',
#  'Ismail Merchant',
#  'Ismail',
#  'Merchant',
#  'Merchant',
#  '',
#  'work',
#  'suspect would hard time sitting',
#  'suspect',
#  'suspect',
#  'suspect',
#  '',
#  'suspect',
#  'would hard time sitting',
#  'would hard time sitting',
#  'would',
#  'hard time sitting',
#  '',
#  'hard time sitting',
#  'hard time',
#  'hard time',
#  'hard',
#  'time',
#  'sitting',
#  'sitting',
#  '',
#  '',
#  '',
#  '',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder Shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder Shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder',
#  'positively thrilling combination',
#  'positively thrilling combination',
#  'positively',
#  'thrilling combination',
#  'thrilling',
#  'combination',
#  'ethnography intrigue betrayal deceit murder',
#  'ethnography intrigue betrayal deceit murder',
#  'ethnography',
#  'ethnography',
#  'intrigue betrayal deceit murder',
#  '',
#  'intrigue betrayal deceit murder',
#  'intrigue betrayal deceit murder',
#  'intrigue',
#  'betrayal deceit murder',
#  'betrayal deceit murder',
#  'betrayal',
#  'deceit murder',
#  'deceit murder',
#  'deceit',
#  'deceit',
#  'murder',
#  'Shakespearean tragedy juicy soap opera',
#  'Shakespearean tragedy juicy soap opera',
#  'Shakespearean tragedy',
#  'Shakespearean tragedy',
#  'Shakespearean tragedy',
#  'Shakespearean',
#  'tragedy',
#  '',
#  'juicy soap opera',
#  'juicy soap opera',
#  'juicy',
#  'soap opera',
#  'soap',
#  'opera',
#  'Aggressive selfglorification manipulative whitewash',
#  'Aggressive selfglorification manipulative whitewash',
#  'Aggressive',
#  'selfglorification manipulative whitewash',
#  'selfglorification',
#  'selfglorification',
#  'manipulative whitewash',
#  'manipulative whitewash',
#  'manipulative',
#  'whitewash',
#  'comedydrama nearly epic proportions rooted sincere performance title character undergoing midlife crisis',
#  'comedydrama nearly epic proportions',
#  'comedydrama',
#  'comedydrama',
#  'nearly epic proportions',
#  'nearly epic proportions',
#  'nearly epic',
#  'nearly',
#  'epic',
#  'proportions',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'rooted sincere performance',
#  'rooted',
#  'sincere performance',
#  '',
#  'sincere performance',
#  'sincere performance',
#  'sincere',
#  'performance',
#  'title character undergoing midlife crisis',
#  '',
#  'title character undergoing midlife crisis',
#  'title character',
#  'title character',
#  'title',
#  'character',
#  'undergoing midlife crisis',
#  'undergoing',
#  'midlife crisis',
#  'midlife',
#  'crisis',
#  'Narratively Trouble Every plodding mess',
#  'Narratively',
#  'Trouble Every plodding mess',
#  'Trouble Every plodding mess',
#  'Trouble Every',
#  'Trouble',
#  'Every',
#  'Every',
#  '',
#  'plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'plodding',
#  'mess',
#  'Importance Being Earnest thick plays like reading Bartlett Familiar Quotations',
#  'Importance',
#  'Importance',
#  'Being Earnest thick plays like reading Bartlett Familiar Quotations',
#  'Being Earnest thick plays like reading Bartlett Familiar Quotations',
#  'Being',
#  'Earnest thick plays like reading Bartlett Familiar Quotations',
#  'Earnest',
#  'Earnest',
#  'thick plays like reading Bartlett Familiar Quotations',
#  '',
#  'thick plays like reading Bartlett Familiar Quotations',
#  'thick',
#  'plays like reading Bartlett Familiar Quotations',
#  '',
#  'plays like reading Bartlett Familiar Quotations',
#  '',
#  'plays like reading Bartlett Familiar Quotations',
#  '',
#  'plays like reading Bartlett Familiar Quotations',
#  'plays',
#  'like reading Bartlett Familiar Quotations',
#  'like',
#  'reading Bartlett Familiar Quotations',
#  'reading',
#  'reading',
#  'Bartlett Familiar Quotations',
#  '',
#  'Bartlett Familiar Quotations',
#  'Bartlett',
#  'Bartlett',
#  'Familiar Quotations',
#  'Familiar',
#  'Quotations',
#  'leave much',
#  'leave much',
#  'leave much',
#  'leave much',
#  '',
#  '',
#  '',
#  'leave much',
#  'leave',
#  'leave',
#  '',
#  'much',
#  'could hate reason',
#  'could hate reason',
#  'could hate reason',
#  'could',
#  'hate reason',
#  'hate',
#  'hate',
#  'reason',
#  'reason',
#  'reason',
#  '',
#  'reason',
#  'There little recommend Snow Dogs unless considers cliched dialogue perverse escapism source high hilarity',
#  'There',
#  'little recommend Snow Dogs unless considers cliched dialogue perverse escapism source high hilarity',
#  'little recommend Snow Dogs unless considers cliched dialogue perverse escapism source high hilarity',
#  'little recommend Snow Dogs',
#  'little recommend Snow Dogs',
#  'little recommend Snow Dogs',
#  'little',
#  'recommend Snow Dogs',
#  'recommend Snow Dogs',
#  'recommend',
#  'Snow Dogs',
#  'Snow',
#  'Dogs',
#  'unless considers cliched dialogue perverse escapism source high hilarity',
#  'unless',
#  'considers cliched dialogue perverse escapism source high hilarity',
#  'considers cliched dialogue perverse escapism source high hilarity',
#  'considers',
#  'cliched dialogue perverse escapism source high hilarity',
#  'cliched dialogue perverse escapism',
#  'cliched dialogue',
#  'cliched dialogue',
#  'cliched',
#  'dialogue',
#  'perverse escapism',
#  'perverse',
#  'escapism',
#  'source high hilarity',
#  'source',
#  'source',
#  'high hilarity',
#  'high hilarity',
#  'high',
#  'hilarity',
#  'Kung Oedekerk realization childhood dream martialarts flick proves sometimes dreams youth remain',
#  'Kung',
#  'Kung',
#  '',
#  'Oedekerk realization childhood dream martialarts flick proves sometimes dreams youth remain',
#  'Oedekerk realization childhood dream martialarts flick proves sometimes dreams youth remain',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream',
#  'Oedekerk realization',
#  'Oedekerk',
#  'Oedekerk',
#  'realization',
#  'childhood dream',
#  'childhood dream',
#  '',
#  'childhood dream',
#  'childhood',
#  'dream',
#  'martialarts flick',
#  'martialarts flick',
#  '',
#  'martialarts flick',
#  'martialarts flick',
#  'martialarts flick',
#  'martialarts',
#  'flick',
#  'proves sometimes dreams youth remain',
#  'proves',
#  'sometimes dreams youth remain',
#  'sometimes dreams youth remain',
#  'sometimes',
#  'dreams youth remain',
#  'dreams youth',
#  'dreams',
#  'dreams',
#  'youth',
#  'youth',
#  'remain',
#  '',
#  'remain',
#  'remain',
#  '',
#  '',
#  'performances absolute',
#  'performances',
#  'performances',
#  'absolute',
#  'absolute',
#  '',
#  'absolute',
#  '',
#  'absolute',
#  'absolute',
#  '',
#  'Fresnadillo something serious ways extravagant chance distort perspective throw path good sense',
#  'Fresnadillo',
#  'something serious ways extravagant chance distort perspective throw path good sense',
#  'something serious ways extravagant chance distort perspective throw path good sense',
#  '',
#  'something serious ways extravagant chance distort perspective throw path good sense',
#  'something',
#  'serious ways extravagant chance distort perspective throw path good sense',
#  'serious',
#  'ways extravagant chance distort perspective throw path good sense',
#  'ways extravagant chance distort perspective throw path good sense',
#  '',
#  'ways extravagant chance distort perspective throw path good sense',
#  '',
#  'ways extravagant chance distort perspective throw path good sense',
#  'ways',
#  'ways',
#  'extravagant chance distort perspective throw path good sense',
#  '',
#  'extravagant chance distort perspective throw path good sense',
#  'extravagant chance',
#  'extravagant',
#  'chance',
#  'distort perspective throw path good sense',
#  '',
#  'distort perspective throw path good sense',
#  'distort perspective',
#  'distort perspective',
#  'distort',
#  'perspective',
#  '',
#  'perspective',
#  'throw path good sense',
#  'throw',
#  'throw',
#  '',
#  'path good sense',
#  '',
#  'path good sense',
#  'path',
#  'path',
#  'good sense',
#  'good sense',
#  'sense',
#  'still like Moonlight Mile better judgment damned',
#  'still like Moonlight Mile better judgment damned',
#  'still',
#  'like Moonlight Mile better judgment damned',
#  'like Moonlight Mile better judgment damned',
#  'Moonlight Mile better judgment damned',
#  'Moonlight Mile better judgment',
#  'Moonlight',
#  'Mile better judgment',
#  'Mile',
#  'better judgment',
#  'better judgment',
#  'better',
#  'judgment',
#  'damned',
#  'damned',
#  'welcome relief baseball movies hard mythic sweet modest ultimately winning story',
#  'welcome relief baseball movies hard mythic',
#  'welcome relief',
#  'welcome relief',
#  'welcome',
#  'relief',
#  'baseball movies hard mythic',
#  'baseball movies hard mythic',
#  'baseball movies',
#  'baseball',
#  'movies',
#  'hard mythic',
#  'hard mythic',
#  '',
#  'hard mythic',
#  '',
#  'hard mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest',
#  'sweet modest',
#  'sweet modest',
#  'sweet',
#  'sweet',
#  'modest',
#  'ultimately winning story',
#  'ultimately',
#  'winning story',
#  'winning',
#  'bilingual charmer like woman inspired',
#  'bilingual charmer',
#  'bilingual charmer',
#  'bilingual charmer',
#  'bilingual',
#  'charmer',
#  'like woman inspired',
#  'like woman inspired',
#  'woman inspired',
#  'woman',
#  'woman',
#  'inspired',
#  '',
#  'inspired',
#  'inspired',
#  'Like less dizzily gorgeous companion Wong Mood Love much Hong Kong movie despite mainland setting',
#  'Like less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous',
#  'less',
#  'dizzily gorgeous',
#  'dizzily',
#  'gorgeous',
#  'companion',
#  '',
#  '',
#  'Wong Mood Love much Hong Kong movie despite mainland setting',
#  'Wong',
#  'Mood Love much Hong Kong movie despite mainland setting',
#  'Mood Love much Hong Kong movie despite mainland setting',
#  'Mood Love much Hong Kong movie',
#  'Mood Love much Hong Kong movie',
#  'Mood Love much Hong Kong movie',
#  'Mood',
#  'Mood',
#  'Love much Hong Kong movie',
#  'Love much Hong Kong movie',
#  'Love much',
#  'Love',
#  'Love',
#  '',
#  'much',
#  '',
#  'Hong Kong movie',
#  'Hong Kong movie',
#  'Hong',
#  'Kong movie',
#  'Kong',
#  'movie',
#  'despite mainland setting',
#  'despite',
#  'mainland setting',
#  '',
#  'mainland setting',
#  'mainland',
#  'setting',
#  'inept bigscreen remakes Avengers Wild Wild West',
#  'inept bigscreen remakes Avengers Wild Wild West',
#  'inept',
#  '',
#  'inept',
#  'bigscreen remakes Avengers Wild Wild West',
#  'bigscreen remakes Avengers Wild Wild West',
#  'bigscreen remakes',
#  'bigscreen',
#  'remakes',
#  'Avengers Wild Wild West',
#  'Avengers Wild Wild West',
#  'Avengers',
#  'Avengers',
#  'Avengers',
#  'Wild Wild West',
#  'Wild Wild West',
#  'Wild',
#  'Wild West',
#  'West',
#  'everything expect nothing',
#  'everything expect nothing',
#  'everything expect nothing',
#  'everything expect nothing',
#  'everything',
#  'expect nothing',
#  'expect nothing',
#  '',
#  'expect nothing',
#  'expect nothing',
#  'expect',
#  'expect',
#  'nothing',
#  'nothing',
#  '',
#  'Best indie year',
#  'Best',
#  'indie year',
#  'indie year',
#  'indie year',
#  'indie year',
#  'indie',
#  'year',
#  'year',
#  'year',
#  '',
#  '',
#  'Hatfield Hicks make oddest couples sense movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'Hatfield Hicks make oddest couples sense movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'Hatfield Hicks make oddest couples',
#  'Hatfield Hicks make oddest couples',
#  'Hatfield Hicks make oddest couples',
#  'Hatfield Hicks',
#  'Hatfield',
#  'Hatfield',
#  'Hicks',
#  'make oddest couples',
#  'make',
#  'oddest couples',
#  'oddest',
#  'oddest',
#  'couples',
#  'couples',
#  'sense movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'sense',
#  'sense',
#  'movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'movie',
#  'becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'becomes study gambles publishing world',
#  'becomes study gambles publishing world',
#  'becomes',
#  'study gambles publishing world',
#  'study',
#  'study',
#  'gambles publishing world',
#  'gambles publishing world',
#  'gambles',
#  'gambles',
#  'publishing world',
#  'publishing world',
#  'publishing world',
#  'publishing',
#  'world',
#  'offering case study exists apart movie political ramifications',
#  'offering',
#  'case study exists apart movie political ramifications',
#  'case study',
#  'case study',
#  'case',
#  'exists apart movie political ramifications',
#  'exists apart movie political ramifications',
#  'exists apart',
#  'exists',
#  'apart',
#  'movie political ramifications',
#  'movie political ramifications',
#  'movie political ramifications',
#  'movie',
#  'movie',
#  'political ramifications',
#  'political',
#  'ramifications',
#  'like going house party watching host defend frothing exgirlfriend',
#  'like going house party watching host defend frothing exgirlfriend',
#  'like going house party watching host defend frothing exgirlfriend',
#  'like going house party watching host defend frothing exgirlfriend',
#  'going house party watching host defend frothing exgirlfriend',
#  'going house party',
#  'going house party',
#  'going',
#  'house party',
#  'house party',
#  'house party',
#  'house',
#  'party',
#  'watching host defend frothing exgirlfriend',
#  'watching',
#  'host defend frothing exgirlfriend',
#  'host',
#  'host',
#  'defend frothing exgirlfriend',
#  'defend',
#  'defend',
#  '',
#  'frothing exgirlfriend',
#  '',
#  'frothing exgirlfriend',
#  'frothing exgirlfriend',
#  'frothing',
#  'exgirlfriend',
#  'That Chuck Norris grenade occurs times Windtalkers good indication seriousminded film',
#  'That Chuck Norris grenade',
#  'Chuck Norris grenade',
#  'Chuck Norris grenade',
#  'Chuck',
#  'Norris grenade',
#  'Norris',
#  'grenade',
#  '',
#  'grenade',
#  'grenade',
#  '',
#  '',
#  '',
#  'occurs times Windtalkers good indication seriousminded film',
#  'occurs times Windtalkers good indication seriousminded film',
#  'occurs',
#  'times Windtalkers good indication seriousminded film',
#  'times Windtalkers',
#  'times',
#  'times',
#  '',
#  'times',
#  'Windtalkers',
#  '',
#  'Windtalkers',
#  'good indication seriousminded film',
#  'good indication seriousminded film',
#  'good indication',
#  'good indication',
#  'indication',
#  'seriousminded film',
#  'seriousminded film',
#  '',
#  'seriousminded film',
#  'seriousminded film',
#  'seriousminded',
#  'film',
#  'film',
#  'plot romantic comedy boilerplate start finish',
#  'plot',
#  'plot',
#  'romantic comedy boilerplate start finish',
#  'romantic comedy boilerplate start finish',
#  'romantic comedy boilerplate start finish',
#  'romantic comedy boilerplate start',
#  'romantic comedy boilerplate',
#  'romantic',
#  'comedy boilerplate',
#  'comedy',
#  'boilerplate',
#  'start',
#  'start',
#  'finish',
#  'finish',
#  'arrives impeccable pedigree mongrel almost indecipherable plot complications',
#  'arrives impeccable pedigree mongrel almost indecipherable plot complications',
#  'arrives impeccable pedigree mongrel almost indecipherable plot complications',
#  'arrives',
#  'impeccable pedigree mongrel almost indecipherable plot complications',
#  'impeccable pedigree mongrel almost indecipherable plot complications',
#  'impeccable pedigree mongrel almost',
#  'impeccable pedigree mongrel',
#  'impeccable pedigree mongrel',
#  'impeccable pedigree mongrel',
#  'impeccable pedigree mongrel',
#  'impeccable',
#  'pedigree mongrel',
#  'pedigree',
#  'mongrel',
#  'mongrel',
#  'mongrel',
#  '',
#  'almost',
#  'indecipherable plot complications',
#  'indecipherable',
#  'plot complications',
#  'complications',
#  'film clearly means preach exclusively converted',
#  'film clearly means',
#  'film',
#  'clearly means',
#  'clearly means',
#  'clearly',
#  'means',
#  'means',
#  'preach exclusively converted',
#  'preach exclusively converted',
#  'preach exclusively',
#  'preach',
#  'exclusively',
#  'converted',
#  'converted',
#  'converted',
#  'While Importance Being Earnest offers opportunities occasional smiles chuckles give reason theater beyond Wilde actors performances',
#  'While Importance Being Earnest offers opportunities occasional smiles chuckles',
#  'While',
#  'Importance Being Earnest offers opportunities occasional smiles chuckles',
#  'Importance Being Earnest',
#  'Being Earnest',
#  'Being Earnest',
#  'offers opportunities occasional smiles chuckles',
#  'offers opportunities occasional smiles',
#  'offers opportunities occasional smiles',
#  'offers',
#  'opportunities occasional smiles',
#  'opportunities',
#  'occasional smiles',
#  'occasional smiles',
#  'occasional',
#  'smiles',
#  'chuckles',
#  'give reason theater beyond Wilde actors performances',
#  'give reason theater beyond Wilde actors performances',
#  'give reason theater beyond Wilde actors performances',
#  'give reason theater beyond Wilde actors performances',
#  'give reason theater beyond Wilde actors performances',
#  'give',
#  'give',
#  'reason theater beyond Wilde actors performances',
#  'reason theater beyond Wilde actors performances',
#  'theater beyond Wilde actors performances',
#  'theater beyond Wilde actors performances',
#  'theater',
#  'theater',
#  'theater',
#  'theater',
#  'beyond Wilde actors performances',
#  'beyond',
#  'Wilde actors performances',
#  'Wilde',
#  'Wilde',
#  'Wilde',
#  'Wilde',
#  'actors performances',
#  'actors',
#  'actors',
#  'actors',
#  '',
#  'latest vapid actor exercise appropriate structure Arthur Schnitzler Reigen',
#  'latest',
#  'latest',
#  'vapid actor exercise appropriate structure Arthur Schnitzler Reigen',
#  'vapid actor exercise appropriate structure Arthur Schnitzler Reigen',
#  'vapid actor exercise',
#  'vapid',
#  'actor exercise',
#  'actor',
#  'actor',
#  'exercise',
#  'appropriate structure Arthur Schnitzler Reigen',
#  'appropriate structure Arthur Schnitzler Reigen',
#  'appropriate structure',
#  'appropriate',
#  'structure',
#  'structure',
#  'Arthur Schnitzler Reigen',
#  'Arthur Schnitzler Reigen',
#  'Arthur Schnitzler',
#  'Arthur',
#  'Schnitzler',
#  'Schnitzler',
#  'Reigen',
#  'More vaudeville show wellconstructed narrative terms inoffensive actually rather sweet',
#  'More vaudeville show wellconstructed narrative terms inoffensive actually rather sweet',
#  'More vaudeville show wellconstructed narrative',
#  'More vaudeville show wellconstructed narrative',
#  'More vaudeville show wellconstructed narrative',
#  'More vaudeville',
#  'vaudeville',
#  'show wellconstructed narrative',
#  'show',
#  'wellconstructed narrative',
#  '',
#  'wellconstructed narrative',
#  'wellconstructed',
#  'narrative',
#  'terms inoffensive actually rather sweet',
#  'terms',
#  '',
#  'terms',
#  '',
#  'terms',
#  'inoffensive actually rather sweet',
#  'inoffensive actually rather sweet',
#  'inoffensive actually rather sweet',
#  'inoffensive actually',
#  'inoffensive',
#  'inoffensive',
#  'actually',
#  'rather sweet',
#  'rather',
#  'Nothing runofthemill action flick',
#  'runofthemill action flick',
#  'runofthemill action',
#  'runofthemill action',
#  'runofthemill action',
#  'runofthemill action',
#  'runofthemill',
#  'action',
#  'flick',
#  'Hampered paralyzed selfindulgent script aims poetry ends sounding like satire',
#  'Hampered paralyzed selfindulgent script aims poetry ends sounding like satire',
#  'Hampered paralyzed selfindulgent script',
#  'Hampered paralyzed selfindulgent script',
#  'Hampered paralyzed',
#  'Hampered',
#  'paralyzed',
#  'paralyzed',
#  'paralyzed',
#  '',
#  'paralyzed',
#  'paralyzed',
#  'selfindulgent script',
#  'selfindulgent script',
#  'selfindulgent script',
#  'selfindulgent',
#  'script',
#  '',
#  'aims poetry ends sounding like satire',
#  'aims poetry ends sounding like satire',
#  'aims poetry',
#  'aims poetry',
#  'aims',
#  'poetry',
#  'poetry',
#  'ends sounding like satire',
#  'ends',
#  'ends',
#  '',
#  'sounding like satire',
#  'sounding',
#  'like satire',
#  'satire',
#  'first computergenerated feature cartoon feel like movies makes glacial pacing early',
#  'first computergenerated feature cartoon feel like movies makes glacial pacing early',
#  'first computergenerated feature cartoon feel like movies',
#  'first computergenerated feature cartoon feel like movies',
#  'first computergenerated feature cartoon feel like movies',
#  '',
#  '',
#  '',
#  'first computergenerated feature cartoon feel like movies',
#  'first computergenerated feature cartoon feel like movies',
#  'first computergenerated feature cartoon',
#  'first computergenerated feature cartoon',
#  'first',
#  'computergenerated feature cartoon',
#  'computergenerated',
#  'feature cartoon',
#  'feature',
#  'cartoon',
#  'feel like movies',
#  'feel like movies',
#  'feel',
#  'like movies',
#  'movies',
#  '',
#  'makes glacial pacing early',
#  'makes glacial pacing early',
#  'makes glacial pacing',
#  'makes',
#  'glacial pacing',
#  'glacial pacing',
#  'glacial pacing',
#  'glacial',
#  'pacing',
#  'early',
#  'early',
#  'There little sense going makers serve cliches considerable dash',
#  'There little sense going makers serve cliches considerable dash',
#  'There little sense going',
#  'There little sense going',
#  'There little sense going',
#  'little sense going',
#  'little sense going',
#  'little sense',
#  'little',
#  'going',
#  'going',
#  'going',
#  'going',
#  'going',
#  '',
#  'makers serve cliches considerable dash',
#  'makers',
#  'makers',
#  'serve cliches considerable dash',
#  'serve',
#  'serve',
#  'cliches considerable dash',
#  'cliches',
#  'cliches',
#  'considerable dash',
#  'considerable dash',
#  'considerable',
#  'dash',
#  'Cattaneo followed runaway success first film Full Monty something different',
#  'Cattaneo',
#  'followed runaway success first film Full Monty something different',
#  'followed runaway success first film Full Monty something different',
#  'followed runaway success first film Full Monty something different',
#  'followed runaway success first film Full Monty something different',
#  'followed runaway success first film Full Monty',
#  'followed',
#  'runaway success first film Full Monty',
#  'runaway success',
#  'runaway success',
#  'runaway',
#  'success',
#  'first film Full Monty',
#  'first film Full Monty',
#  'first film Full Monty',
#  'first film',
#  'first film',
#  'first film',
#  'Full Monty',
#  'Full Monty',
#  'Full',
#  'Monty',
#  'something different',
#  'something different',
#  'different',
#  'They unnamed easily substitutable forces serve whatever terror heroes horror movies avoid',
#  'They',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies avoid',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies avoid',
#  '',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies avoid',
#  'unnamed easily substitutable forces',
#  'unnamed easily substitutable forces',
#  'unnamed easily substitutable',
#  'unnamed',
#  'easily substitutable',
#  'easily substitutable',
#  'easily',
#  'substitutable',
#  'forces',
#  'serve whatever terror heroes horror movies avoid',
#  'serve whatever terror heroes horror movies avoid',
#  'whatever terror heroes horror movies avoid',
#  'whatever terror heroes horror movies avoid',
#  'whatever',
#  'terror heroes horror movies avoid',
#  'terror',
#  'heroes horror movies avoid',
#  'heroes horror movies',
#  'heroes',
#  'heroes',
#  'horror movies',
#  'horror movies',
#  'horror',
#  'avoid',
#  ...]

# %% [markdown]
# Word Frequency

# %%
text_list=[]  
for index, row in train.iterrows(): 
    text_list.append((row['Phrase'])) 
text_list

total_words=''.join(text_list)
total_words=word_tokenize(total_words)

# %%
freq_words=FreqDist(total_words)
word_frequency=FreqDist(freq_words)

# %%
# 10 common words
print(word_frequency.most_common(10))
# Out:
# [('film', 3259), ('movie', 2892), ('like', 1968), ('story', 1204), ('much', 1085), ('good', 1069), ('even', 1041), ('characters', 994), ('little', 976), ('make', 838)]

# %%
# visualize 
pd.DataFrame(word_frequency,index=[0]).T.sort_values(by=[0],ascending=False).head(20).plot(kind='bar',figsize=(16,6),grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Common words used for negative sentiment

# %%
neg_text_list=[]  
for index, row in train[train['Sentiment']==0].iterrows(): 
    neg_text_list.append((row['Phrase'])) 
neg_text_list

neg_total_words=' '.join(neg_text_list)
neg_total_words=word_tokenize(neg_total_words)

neg_freq_words=FreqDist(neg_total_words)
neg_word_frequency=FreqDist(neg_freq_words)

# %%
# visualize 
pd.DataFrame(neg_word_frequency,index=[0]).T.sort_values(by=[0],ascending=False).head(20).plot(kind='bar',figsize=(16,6),grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Common words used for positive sentiment

# %%
pos_text_list=[]  
for index, row in train[train['Sentiment']==4].iterrows(): 
    pos_text_list.append((row['Phrase'])) 
pos_text_list

pos_total_words=' '.join(pos_text_list)
pos_total_words=word_tokenize(pos_total_words)

pos_freq_words=FreqDist(pos_total_words)
pos_word_frequency=FreqDist(pos_freq_words)

# %%
# visualize 
pd.DataFrame(pos_word_frequency,index=[0]).T.sort_values(by=[0],ascending=False).head(20).plot(kind='bar',figsize=(16,6),grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div align='center'><H1>Part 2 Machine Learning Modeling</H1></div>

# %% [markdown]
# Prepare Training data

# %% [markdown]
# Create Bag of words with CountVectorizer

# %%
train['tokenized_words']=train['Phrase'].apply(lambda x:word_tokenize(x))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage good goos...
# 1         2           1    series escapades demonstrating adage good goose
# 2         3           1                                             series
# 3         4           1
# 4         5           1                                             series
#
#    Sentiment    sentiment_class  PhraseLength  \
# 0          1  somewhat negative           108
# 1          2            neutral            47
# 2          2            neutral             6
# 3          2            neutral             0
# 4          2            neutral             6
#
#                                      tokenized_words
# 0  [series, escapades, demonstrating, adage, good...
# 1  [series, escapades, demonstrating, adage, good...
# 2                                           [series]
# 3                                                 []
# 4                                           [series]

# %%
count_vectorizer=CountVectorizer()
phrase_dtm=count_vectorizer.fit_transform(train['Phrase'])

# %%
phrase_dtm.shape
# Out:
# (156060, 15746)

# %%
print(phrase_dtm[:1])
# Out:
#   (0, 12177)	1
#   (0, 4629)	1
#   (0, 3545)	1
#   (0, 260)	1
#   (0, 5912)	2
#   (0, 5936)	1
#   (0, 508)	1
#   (0, 5677)	1
#   (0, 9431)	1
#   (0, 577)	1
#   (0, 9293)	1
#   (0, 569)	1
#   (0, 9002)	1
#   (0, 13252)	1

# %% [markdown]
# Split data into training and validation sets (70:30) ratio

# %%
X_train,X_val,y_train,y_val=train_test_split(phrase_dtm,train['Sentiment'],test_size=0.3, random_state=38)
X_train.shape,y_train.shape,X_val.shape,y_val.shape
# Out:
# ((109242, 15746), (109242,), (46818, 15746), (46818,))

# %% [markdown]
# Train Logistic Regression model

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Measure model performance

# %%
accuracy_score(model.predict(X_val),y_val)*100
# Out:
# 63.744713571703194

# %% [markdown]
# Free up memory for tf-idf

# %%
del X_train
del X_val
del y_train
del y_val

# %% [markdown]
# Preparing data with tf-idf

# %%
tfidf=TfidfVectorizer()
tfidf_dtm=tfidf.fit_transform(train['Phrase'])

# %%
tfidf_dtm
# Out:
# <156060x15746 sparse matrix of type '<class 'numpy.float64'>'
# 	with 565253 stored elements in Compressed Sparse Row format>

# %%
print(tfidf_dtm[:1])
# Out:
#   (0, 13252)	0.15483885464140698
#   (0, 9002)	0.16390601072844335
#   (0, 569)	0.2669103278586383
#   (0, 9293)	0.2318499854417672
#   (0, 577)	0.3185894330159137
#   (0, 9431)	0.23343820204433488
#   (0, 5677)	0.3214648599648944
#   (0, 508)	0.1952499443710657
#   (0, 5936)	0.2836700681840777
#   (0, 5912)	0.3236621284896056
#   (0, 260)	0.30373183690291966
#   (0, 3545)	0.3005531998811136
#   (0, 4629)	0.3368760339635396
#   (0, 12177)	0.2131027778632671

# %%
X_train,X_val,y_train,y_val=train_test_split(tfidf_dtm,train['Sentiment'],test_size=0.3, random_state=38)
X_train.shape,y_train.shape,X_val.shape,y_val.shape
# Out:
# ((109242, 15746), (109242,), (46818, 15746), (46818,))

# %%
tfidf_model=LogisticRegression()

# %%
tfidf_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
accuracy_score(tfidf_model.predict(X_val),y_val)*100
# Out:
# 62.37985390234525

# %% [markdown]
# Predict on test data

# %%
print(tfidf_model.predict(X_val)[0:10])
# Out:
# [3 2 2 2 2 2 2 3 2 3]

# %% [markdown]
# new data prediction function

# %%
def predict_new_text(text):
    tfidf_text=tfidf.transform([text])
    return tfidf_model.predict(tfidf_text)

# %%
predict_new_text("The movie is bad and sucks!")
# Out:
# array([0], dtype=int64)

# %% [markdown]
# Prepare Test Data

# %%
test['Phrase']=test['Phrase'].apply(lambda x:remove_punctuation(x))
test['Phrase']=test['Phrase'].apply(lambda x:words_with_more_than_three_chars(x))
test['Phrase']=test['Phrase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
test_dtm=tfidf.transform(test['Phrase'])

# %%
# Predict with test data
test['Sentiment']=tfidf_model.predict(test_dtm)
test.set_index=test['PhraseId']
test.head()
# Out:
#    PhraseId  SentenceId                                         Phrase  \
# 0    156061        8545  intermittently pleasing mostly routine effort
# 1    156062        8545  intermittently pleasing mostly routine effort
# 2    156063        8545
# 3    156064        8545  intermittently pleasing mostly routine effort
# 4    156065        8545         intermittently pleasing mostly routine
#
#    Sentiment
# 0          3
# 1          3
# 2          2
# 3          3
# 4          3

# %%
# save results to csv file
# test.to_csv('Submission.csv',columns=['PhraseId','Sentiment'],index=False)
