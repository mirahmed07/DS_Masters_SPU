# %% [markdown]
# # Assignment 6
#
# Please answer each question to the corresponding question cell below. Your final code must have the code as well as the output of your code. You can use Saint Peter's [Azure Databricks](https://adb-7130196131129306.6.azuredatabricks.net/?o=7130196131129306#) to do this assignment.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Q1
#
# Spark [catalog](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.Catalog.html#pyspark-sql-catalog) has database(s), local and external tables, functions, etc. Show the current database you are connected in Spark.

# %%
spark.catalog.currentDatabase()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[135]: &#39;default&#39;</div>

# %% [markdown]
# ### Q2
#
# List all tables under the current database.

# %%
spark.catalog.listTables('default')
# Alternate method
# spark.catalog.listTables(spark.catalog.currentDatabase())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[136]: [Table(name=&#39;actual_payments_2_csv&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;appl_stock&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;clients_1__csv&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;clients_9&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;clients_csv&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;containsnull&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;containsnull_&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;customer_orders&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;customer_orders_csv&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;fakefriends_header&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;people&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False),
#  Table(name=&#39;people10m&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False),
#  Table(name=&#39;products&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False),
#  Table(name=&#39;sales&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;sales_9&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;sales_csv&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;walmart_stock_csv&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;winequality_white&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False)]</div>

# %% [markdown]
# ### Q3
#
# Show all the databases available in Spark.

# %%
spark.sql('show databases').show(truncate=False)
# Alternate method
# spark.catalog.listDatabases()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------------------------------------------------+
# databaseName                                                           |
# +-----------------------------------------------------------------------+
# dbacademy_mahmed6_saintpeters_edu_aspwd_asp_2_1_spark_sql              |
# dbacademy_mahmed6_saintpeters_edu_aspwd_asp_3_1l_revenue_by_traffic_lab|
# dbacademy_mahmed6_saintpeters_edu_aspwd_asp_6_1_delta_lake             |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_1_1l_explore_datasets_lab     |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_2_1_spark_sql                 |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_2_1l_spark_sql_lab            |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_2_2_reader_writer             |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_2_2l_ingesting_data_lab       |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_2_3_dataframe_column          |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_2_3l_purchase_revenues_lab    |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_1_aggregation               |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_1l_revenue_by_traffic_lab   |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_2_datetimes                 |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_2l_active_users_lab         |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_3_complex_types             |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_3l_users                    |
# dbacademy_mdas_saintpeters_edu_aspwd_asp_3_4_additional_functions      |
# dbacademy_msenturk_saintpeters_edu_aspwd_asp_1_1_databricks_platform   |
# dbacademy_msenturk_saintpeters_edu_aspwd_asp_1_1l_explore_datasets_lab |
# dbacademy_msenturk_saintpeters_edu_aspwd_asp_2_1_spark_sql             |
# +-----------------------------------------------------------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### Q4
#
# Using `sales` table that you have discovered in Q2, find the total `Quantity` and sum of the `SaleAmount` for each combination of `State` and `City`.

# %%
# spark.catalog.listColumns("sales")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT State, City, SUM(Quantity) as Total_quantity, SUM(SaleAmount) as Total_sale_amt FROM sales GROUP BY State, City ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>City</th><th>Total_quantity</th><th>Total_sale_amt</th></tr></thead><tbody><tr><td>Connecticut</td><td>Glastonbury</td><td>5</td><td>705.0</td></tr><tr><td>Louisiana</td><td>Lafayette</td><td>216</td><td>31369.999908447266</td></tr><tr><td>Colorado</td><td>Pueblo West</td><td>138</td><td>20118.199996948242</td></tr><tr><td>Maine</td><td>Biddeford</td><td>194</td><td>26125.7001953125</td></tr><tr><td>MA</td><td>Attleboro</td><td>68</td><td>9621.0</td></tr><tr><td>MA</td><td>Dracut</td><td>39</td><td>5674.5</td></tr><tr><td>Illinois</td><td>Saint Charles</td><td>376</td><td>47497.749755859375</td></tr><tr><td>MO</td><td>Kansas City</td><td>184</td><td>25127.200439453125</td></tr><tr><
# %% [markdown]
# ### Q5
#
# Below are some of the data types of the `sales` DataFrame that you have interacted with. Your collegue find out that some of the data types are not set properly.
#
# ```
# >>> df.printSchema()
# root
#  |-- RowID: string (nullable = true)
#  |-- OrderID: string (nullable = true)
#  |-- OrderDate: string (nullable = true)
#  ...
#  |-- SaleAmount: float (nullable = true)
#  |-- CustomerName: string (nullable = true)
#  ...
#  |-- WageMargin: string (nullable = true)
#
# ```
#
# Convert `OrderDate` to DateType, `SaleAmount` to DecimalType, and `WageMargin` to FloatType.

# %%
df = spark.sql("SELECT RowID, OrderID, OrderDate, SaleAmount, CustomerName, WageMargin from sales")
# Alternate method
# df = spark.read.table("default.sales").select('RowID', 'OrderID', 'OrderDate', 'SaleAmount', 'CustomerName', 'WageMargin')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>RowID</th><th>OrderID</th><th>OrderDate</th><th>SaleAmount</th><th>CustomerName</th><th>WageMargin</th></tr></thead><tbody><tr><td>1</td><td>3</td><td>2010-10-13</td><td>1152.0</td><td>Muhammed MacIntyre</td><td>0.70</td></tr><tr><td>2</td><td>6</td><td>2012-02-20</td><td>277.2</td><td>Ruben Staebel</td><td>0.46</td></tr><tr><td>3</td><td>32</td><td>2011-07-15</td><td>3022.5</td><td>Liz Greer</td><td>0.40</td></tr><tr><td>4</td><td>32</td><td>2011-07-15</td><td>2730.0</td><td>Liz Greer</td><td>0.58</td></tr><tr><td>5</td><td>32</td><td>2011-07-15</td><td>3312.0</td><td>Liz Greer</td><td>0.67</td></tr><tr><td>6</td><td>32</td><td>2011-07-15</td><td>2160.0</td><td>Liz Greer</td><td>0.59</td></tr><tr><td>7</td><td>35</td><td>2011-10-22</td><td>3492.0</td><td>Julie Knight</td><td>0.48</td></tr><tr><td>8</td><td>35</td><td>2011-10-22</td><td>2079.0</td><td>Julie Knight</td><td>0.55</td></tr><tr><td>9</td><td>36</td><td>2011-11-02</td><td>6210.0</td><td>Sample Manning</td><td>0.66</td></tr><tr><td>10</td><td>65</td><td>2011-03-17</td><td>4704.0</td><td>Tamara O'Brill</td><td>0.55</td></tr><tr><td>11</td><td>66</td><td>2009-01-19</td><td>4477.2</td><td>Arthur Nelson</td><td>0.42</td></tr><tr><td>12</td><td>69</td><td>2009-06-03</td><td>4777.5</td><td>Jonathan Akin</td><td>0.53</td></tr><tr><td>13</td><td>69</td><td>2009-06-03</td><td>3259.2</td><td>Jonathan Akin</td><td>0.50</td></tr><tr><td>14</td><td>70</td><td>2010-12-17</td><td>6518.4</td><td>Helen Kimmel</td><td>0.49</td></tr><tr><td>15</td><td>70</td><td>2010-12-17</td><td>6555.0</td><td>Helen Kimmel</td><td>0.55</td></tr><tr><td>16</td><td>96</td><td>2009-04-16
</td></tr><tr><td>23</td><td>132</td><td>2010-06-10</td><td>3562.50</td><td>Emily Fortune</td><td>0.52</td></tr><tr><td>24</td><td>134</td><td>2012-04-30</td><td>2178.00</td><td>Michael Olson</td><td>0.72</td></tr><tr><td>25</td><td>135</td><td>2011-10-20</td><td>3412.50</td><td>Anne Van Hugh</td><td>0.59</td></tr><tr><td>26</td><td>166</td><td>2011-09-11</td><td>1470.00</td><td>Valerie Pelletier</td><td>0.5</td></tr><tr><td>27</td><td>193</td><td>2010-08-07</td><td>2632.00</td><td>Justin McVee</td><td>0.7</td></tr><tr><td>28</td><td>194</td><td>2012-04-04</td><td>5512.50</td><td>Maria Ferguson</td><td>0.58</td></tr><tr><td>29</td><td>194</td><td>2012-04-04</td><td>806.40</td><td>Maria Ferguson</td><td>0.52</td></tr><tr><td>30</td><td>195</td><td>2010-12-27</td><td>3957.60</td><td>Brad Fisher</td><td>0.5</td></tr><tr><td>31</td><td>197</td><td>2011-04-06</td><td>3187.80</td><td>Penelope Pistole</td><td>0.49</td></tr><tr><td>32</td><td>224</td><td>2009-06-17</td><td>2843.75</td><td>Bart Armstrong</td><td>0.59</td></tr><tr><td>33</td><td>224</td><td>2009-06-17</td><td>4646.40</td><td>Bart Armstrong</td><td>0.47</td></tr><tr><td>34</td><td>224</td><td>2009-06-17</td><td>6336.00</td><td>Bart Armstrong</td><td>0.67</td></tr><tr><td>35</td><td>225</td><td>2011-05-24</td><td>2707.20</td><td>Karen Gilpin</td><td>0.41</td></tr><tr><td>36</td><td>225</td><td>2011-05-24</td><td>114.00</td><td>Karen Gilpin</td><td>0.42</td></tr><tr><td>37</td><td>229</td><td>2010-12-28</td><td>4783.75</td><td>Matt French</td><td>0.54</td></tr><tr><td>38</td><td>229</td><td>2010-12-2 ...

# %%
df_fixed.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- RowID: string (nullable = true)
# -- OrderID: string (nullable = true)
# -- OrderDate: date (nullable = true)
# -- SaleAmount: decimal(10,2) (nullable = true)
# -- CustomerName: string (nullable = true)
# -- WageMargin: float (nullable = true)
#
# </div>

# %% [markdown]
# ### Q6
#
# We want to add another column to this dataset, the initals of the customer's name and surname. However, there is no built in function for it, so you have to make one yourself. Register this function as a UDF. This serializes the function and sends it to executors to be able to transform DataFrame records. Then using this UDF, create a new column with name `CustomerNameInitials`. For example, if name is `John Smith`, the new value should be `JS`.

# %%
from pyspark.sql.types import StringType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@udf(returnType=StringType()) 
def CustomerNameInitials(name):
    return "".join([x[0] for x in name.split(" ")])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_with_ini1 = df_fixed.withColumn("CustomerNameInitials", CustomerNameInitials(col("CustomerName")))
display(df_with_ini1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>RowID</th><th>OrderID</th><th>OrderDate</th><th>SaleAmount</th><th>CustomerName</th><th>WageMargin</th><th>CustomerNameInitials</th></tr></thead><tbody><tr><td>1</td><td>3</td><td>2010-10-13</td><td>1152.00</td><td>Muhammed MacIntyre</td><td>0.7</td><td>MM</td></tr><tr><td>2</td><td>6</td><td>2012-02-20</td><td>277.20</td><td>Ruben Staebel</td><td>0.46</td