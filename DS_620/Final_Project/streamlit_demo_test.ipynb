# %%
import pandas as pd

# %%
ultimate_no_null_df = pd.read_csv("resources/ultimate_no_null.csv")
ultimate_no_null_df.head()
# Out:
#   standard_names  month  year  Confirmed  stringency_index       lat  \
# 0    Afghanistan      1  2020        0.0          0.000000  33.93911
# 1    Afghanistan      2  2020        1.0          2.010690  33.93911
# 2    Afghanistan      3  2020      174.0         40.831935  33.93911
# 3    Afghanistan      4  2020     1952.0         80.740000  33.93911
# 4    Afghanistan      5  2020    13081.0         84.260000  33.93911
#
#          lng  Population (2020)  Density (P/Km²) Infection_rate ISO_2 ISO_3  \
# 0  67.709953           39074280               60        0.0000%    AF   AFG
# 1  67.709953           39074280               60        0.0000%    AF   AFG
# 2  67.709953           39074280               60        0.0004%    AF   AFG
# 3  67.709953           39074280               60        0.0050%    AF   AFG
# 4  67.709953           39074280               60        0.0335%    AF   AFG
#
#    Infection_rate_f
# 0            0.0000
# 1            0.0000
# 2            0.0004
# ...

# %%
ultimate_no_null_df['standard_names'].unique().tolist()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cabo Verde',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo Republic',
#  'DR Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  "Cote d'Ivoire",
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
# ...

# %%
ultimate_no_null_df.iloc[:1]
# Out:
#   standard_names  month  year  Confirmed  stringency_index       lat  \
# 0    Afghanistan      1  2020        0.0               0.0  33.93911
#
#          lng  Population (2020)  Density (P/Km²) Infection_rate ISO_2 ISO_3  \
# 0  67.709953           39074280               60        0.0000%    AF   AFG
#
#    Infection_rate_f
# 0               0.0

# %%
filtered_df = ultimate_no_null_df[ultimate_no_null_df['standard_names']=='Afghanistan'].set_index('month', drop = True)
filtered_df.head()
# Out:
#       standard_names  year  Confirmed  stringency_index       lat        lng  \
# month
# 1        Afghanistan  2020        0.0          0.000000  33.93911  67.709953
# 2        Afghanistan  2020        1.0          2.010690  33.93911  67.709953
# 3        Afghanistan  2020      174.0         40.831935  33.93911  67.709953
# 4        Afghanistan  2020     1952.0         80.740000  33.93911  67.709953
# 5        Afghanistan  2020    13081.0         84.260000  33.93911  67.709953
#
#        Population (2020)  Density (P/Km²) Infection_rate ISO_2 ISO_3  \
# month
# 1               39074280               60        0.0000%    AF   AFG
# 2               39074280               60        0.0000%    AF   AFG
# 3               39074280               60        0.0004%    AF   AFG
# 4               39074280               60        0.0050%    AF   AFG
# 5               39074280               60        0.0335%    AF   AFG
#
#        Infection_rate_f
# month
# 1                0.0000
# ...

# %%
filtered_df[['Confirmed']][filtered_df['standard_names']=='Afghanistan'].iloc[1:2]
# Out:
#        Confirmed
# month
# 2            1.0
