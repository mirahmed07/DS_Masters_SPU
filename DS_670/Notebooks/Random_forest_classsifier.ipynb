# %%
# Dependencies
import pandas as pd
pd.set_option('display.max_columns', 68)
pd.options.display.float_format = '{:,.2f}'.format
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import joblib

# %%
# SQLite dependencies
import sqlite3
from sqlalchemy import create_engine, text
from sqlalchemy import Column, Integer, String, Float
from pandas_profiling import ProfileReport
#  SQLite DB creation and establishing connection
database_path = "NJ_County_DB.sqlite"
engine = create_engine(f"sqlite:///{database_path}", echo=True)
sqlite_connection = engine.connect()

# %%
# (SELECT county_name , year, AVG(house_value_index) AS house_value_index
# FROM nj_zillow_house_value_index GROUP BY 1,2)

# %%
sql_query = """
SELECT * FROM nj_zillow_house_value_index
 AS T1
INNER JOIN nj_population AS T2 ON T1.county_name = T2.county_name AND T1.year=T2.year
INNER JOIN nj_poverty_median_income AS T3 ON T1.county_name = T3.county_name AND T1.year=T3.year
INNER JOIN 
(SELECT county_name , year, AVG(tax_rate) AS tax_rate 
FROM nj_property_tax GROUP BY 1,2)AS T4 ON T1.county_name = T4.county_name AND T1.year=T4.year
INNER JOIN nj_mortgage_rates AS T5 ON T1.year=T5.year
;
"""
all_df = pd.read_sql(sql_query,sqlite_connection)
all_df.info()
# Out:
# 2023-03-24 18:18:50,448 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("
# SELECT * FROM nj_zillow_house_value_index
#  AS T1
# INNER JOIN nj_population AS T2 ON T1.county_name = T2.county_name AND T1.year=T2.year
# INNER JOIN nj_poverty_median_income AS T3 ON T1.county_name = T3.county_name AND T1.year=T3.year
# INNER JOIN
# (SELECT county_name , year, AVG(tax_rate) AS tax_rate
# FROM nj_property_tax GROUP BY 1,2)AS T4 ON T1.county_name = T4.county_name AND T1.year=T4.year
# INNER JOIN nj_mortgage_rates AS T5 ON T1.year=T5.year
# ;
# ")
# 2023-03-24 18:18:50,450 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-24 18:18:50,455 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("
# SELECT * FROM nj_zillow_house_value_index
#  AS T1
# INNER JOIN nj_population AS T2 ON T1.county_name = T2.county_name AND T1.year=T2.year
# INNER JOIN nj_poverty_median_income AS T3 ON T1.county_name = T3.county_name AND T1.year=T3.year
# INNER JOIN
# (SELECT county_name , year, AVG(tax_rate) AS tax_rate
# FROM nj_property_tax GROUP BY 1,2)AS T4 ON T1.county_name = T4.county_name AND T1.year=T4.year
# INNER JOIN nj_mortgage_rates AS T5 ON T1.year=T5.year
# ;
# ")
# 2023-03-24 18:18:50,456 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-24 18:18:50,458 INFO sqlalchemy.engine.Engine
# SELECT * FROM nj_zillow_house_value_index
#  AS T1
# INNER JOIN nj_population AS T2 ON T1.county_name = T2.county_name AND T1.year=T2.year
# INNER JOIN nj_poverty_median_income AS T3 ON T1.county_name = T3.county_name AND T1.year=T3.year
# INNER JOIN
# (SELECT county_name , year, AVG(tax_rate) AS tax_rate
# FROM nj_property_tax GROUP BY 1,2)AS T4 ON T1.county_name = T4.county_name AND T1.year=T4.year
# INNER JOIN nj_mortgage_rates AS T5 ON T1.year=T5.year
# ;
#
# 2023-03-24 18:18:50,459 INFO sqlalchemy.engine.Engine [raw sql] ()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   county_name        1260 non-null   object
#  1   year               1260 non-null   int64
#  2   num_of_bedrooms    1260 non-null   int64
#  3   house_value_index  1260 non-null   float64
#  4   county_name        1260 non-null   object
#  5   est_pop            1260 non-null   int64
#  6   year               1260 non-null   int64
#  7   county_name        1260 non-null   object
#  8   median_hh_income   1260 non-null   int64
#  9   poverty_count      1260 non-null   int64
#  10  poverty_rate       1260 non-null   float64
#  11  st_abb             1260 non-null   object
#  12  year               1260 non-null   int64
#  13  state_code         1260 non-null   object
#  14  county_code        1260 non-null   object
#  15  county_name        1260 non-null   object
#  16  year               1260 non-null   int64
#  17  tax_rate           1260 non-null   float64
#  18  year               1260 non-null   int64
#  19  apr_30             1260 non-null   float64
#  20  points_30          1260 non-null   float64
#  21  apr_15             1260 non-null   float64
#  22  points_15          1260 non-null   float64
# dtypes: float64(7), int64(9), object(7)
# memory usage: 226.5+ KB

# %%
all_df.describe()
# Out:
#           year  num_of_bedrooms  house_value_index    est_pop     year  \
# count 1,260.00         1,260.00           1,260.00   1,260.00 1,260.00
# mean  2,015.50             3.00         301,526.97 423,663.90 2,015.50
# std       3.45             1.41         174,631.35 253,661.54     3.45
# min   2,010.00             1.00          47,502.88  62,341.00 2,010.00
# 25%   2,012.75             2.00         171,183.50 150,928.75 2,012.75
# 50%   2,015.50             3.00         263,753.40 448,449.00 2,015.50
# 75%   2,018.25             4.00         388,531.82 603,111.25 2,018.25
# max   2,021.00             5.00       1,312,995.76 953,819.00 2,021.00
#
#        median_hh_income  poverty_count  poverty_rate     year     year  \
# count          1,260.00       1,260.00      1,260.00 1,260.00 1,260.00
# mean          76,414.14      42,851.11         10.05 2,015.50 2,015.50
# std           18,476.21      32,803.23          4.06     3.45     3.45
# min           45,438.00       4,793.00          3.90 2,010.00 2,010.00
# 25%           61,363.25      16,560.50          6.67 2,012.75 2,012.75
# 50%           74,839.00      36,293.50          9.45 2,015.50 2,015.50
# 75%           87,602.25      63,450.25         13.10 2,018.25 2,018.25
# max          123,708.00     136,161.00         20.10 2,021.00 2,021.00
#
#        tax_rate     year   apr_30  points_30   apr_15  points_15
# count  1,260.00 1,260.00 1,260.00   1,260.00 1,260.00   1,260.00
# mean       3.38 2,015.50     3.92       0.63     3.22       0.60
# std        1.65     3.45     0.50       0.09     0.51       0.09
# min        0.97 2,010.00     2.96       0.48     2.27       0.45
# 25%        2.47 2,012.75     3.66       0.53     2.93       0.49
# 50%        2.97 2,015.50     3.96       0.65     3.19       0.61
# 75%        3.69 2,018.25     4.24       0.72     3.46       0.69
# max        9.66 2,021.00     4.69       0.73     4.10       0.71

# %%
all_df.head()
# Out:
#   county_name  year  num_of_bedrooms  house_value_index county_name  est_pop  \
# 0    ATLANTIC  2010                1         120,414.14    ATLANTIC   274654
# 1    ATLANTIC  2011                1         106,680.39    ATLANTIC   274635
# 2    ATLANTIC  2012                1         100,139.16    ATLANTIC   274657
# 3    ATLANTIC  2013                1          94,991.76    ATLANTIC   274360
# 4    ATLANTIC  2014                1          92,839.52    ATLANTIC   272634
#
#    year county_name  median_hh_income  poverty_count  poverty_rate st_abb  \
# 0  2010    ATLANTIC             51457          36693         13.60     NJ
# 1  2011    ATLANTIC             49983          35108         13.10     NJ
# 2  2012    ATLANTIC             50881          38245         14.20     NJ
# 3  2013    ATLANTIC             51668          46281         17.10     NJ
# 4  2014    ATLANTIC             54208          40761         15.10     NJ
#
#    year state_code county_code county_name  year  tax_rate  year  apr_30  \
# 0  2010        034         001    ATLANTIC  2010      2.67  2010    4.69
# 1  2011        034         001    ATLANTIC  2011      2.65  2011    4.45
# 2  2012        034         001    ATLANTIC  2012      2.73  2012    3.66
# 3  2013        034         001    ATLANTIC  2013      2.87  2013    3.98
# 4  2014        034         001    ATLANTIC  2014      2.84  2014    4.17
#
#    points_30  apr_15  points_15
# 0       0.72    4.10       0.67
# 1       0.72    3.68       0.71
# 2       0.72    2.93       0.68
# 3       0.73    3.10       0.70
# 4       0.59    3.29       0.57

# %%
all_df=all_df.loc[:,~all_df.columns.duplicated()].copy()
all_df
# Out:
#      county_name  year  num_of_bedrooms  house_value_index  est_pop  \
# 0       ATLANTIC  2010                1         120,414.14   274654
# 1       ATLANTIC  2011                1         106,680.39   274635
# 2       ATLANTIC  2012                1         100,139.16   274657
# 3       ATLANTIC  2013                1          94,991.76   274360
# 4       ATLANTIC  2014                1          92,839.52   272634
# ...          ...   ...              ...                ...      ...
# 1255      WARREN  2017                5         337,688.95   105761
# 1256      WARREN  2018                5         348,528.58   105709
# 1257      WARREN  2019                5         352,652.50   105455
# 1258      WARREN  2020                5         365,908.92   105624
# 1259      WARREN  2021                5         433,923.52   110731
#
#       median_hh_income  poverty_count  poverty_rate st_abb state_code  \
# 0                51457          36693         13.60     NJ        034
# 1                49983          35108         13.10     NJ        034
# 2                50881          38245         14.20     NJ        034
# 3                51668          46281         17.10     NJ        034
# 4                54208          40761         15.10     NJ        034
# ...                ...            ...           ...    ...        ...
# 1255             79633           7770          7.40     NJ        034
# 1256             77571           7006          6.70     NJ        034
# 1257             83998           7313          7.10     NJ        034
# 1258             80412           7539          7.30     NJ        034
# 1259             82900          10140          9.30     NJ        034
#
#      county_code  tax_rate  apr_30  points_30  apr_15  points_15
# 0            001      2.67    4.69       0.72    4.10       0.67
# 1            001      2.65    4.45       0.72    3.68       0.71
# 2            001      2.73    3.66       0.72    2.93       0.68
# 3            001      2.87    3.98       0.73    3.10       0.70
# 4            001      2.84    4.17       0.59    3.29       0.57
# ...          ...       ...     ...        ...     ...        ...
# 1255         041      3.28    3.99       0.50    3.27       0.49
# 1256         041      3.32    4.54       0.48    4.00       0.45
# 1257         041      3.36    3.94       0.52    3.39       0.47
# 1258         041      3.40    3.11       0.73    2.60       0.69
# 1259         041      3.44    2.96       0.68    2.27       0.64
#
# [1260 rows x 16 columns]

# %%
# Set features. This will also be used as x values.
X = all_df.drop(['county_name', 'st_abb','state_code','county_code', 'est_pop', 'points_30','points_15',\
                 'tax_rate','poverty_count','apr_30','apr_15'], axis=1)
y = all_df["county_name"]
print(X.shape, y.shape)
# Out:
# (1260, 5) (1260,)

# %%
# Split data into training and testing groups and scale data 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Fit the data into model
rfm = RandomForestClassifier(n_estimators=200)
rfm.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
sorted(zip(rfm.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.3609237487342005, 'poverty_rate'),
#  (0.3103848368846969, 'median_hh_income'),
#  (0.15761129628656217, 'house_value_index'),
#  (0.12514809140252514, 'year'),
#  (0.04593202669201531, 'num_of_bedrooms')]

# %%
predictions = rfm.predict(X_test)
print(f"Training Data Score: {rfm.score(X_train, y_train)}")
print(f"Testing Data Score: {rfm.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.946031746031746

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#     ATLANTIC       0.85      0.85      0.85        13
#       BERGEN       1.00      1.00      1.00        15
#   BURLINGTON       1.00      0.94      0.97        16
#       CAMDEN       1.00      1.00      1.00        14
#     CAPE MAY       1.00      0.94      0.97        16
#   CUMBERLAND       0.94      1.00      0.97        16
#        ESSEX       0.89      0.84      0.86        19
#   GLOUCESTER       0.90      1.00      0.95        18
#       HUDSON       0.80      1.00      0.89        12
#    HUNTERDON       1.00      1.00      1.00        14
#       MERCER       1.00      1.00      1.00        12
#    MIDDLESEX       1.00      1.00      1.00        17
#     MONMOUTH       1.00      1.00      1.00        13
#       MORRIS       0.82      0.82      0.82        17
#        OCEAN       0.94      1.00      0.97        17
#      PASSAIC       1.00      0.77      0.87        13
#        SALEM       1.00      1.00      1.00        16
#     SOMERSET       0.85      0.79      0.81        14
#       SUSSEX       0.94      1.00      0.97        17
#        UNION       1.00      0.92      0.96        13
#       WARREN       1.00      1.00      1.00        13
#
#     accuracy                           0.95       315
#    macro avg       0.95      0.95      0.95       315
# weighted avg       0.95      0.95      0.95       315

# %% [markdown]
# # Prediction array

# %%
beds=3
income=80000
budget=400000
all_df_latest=all_df[all_df['year']==all_df['year'].max()]
# if (income==rfm_array['median_hh_income'])&(budget==rfm_array['house_value_index']) :
rfm_array=pd.DataFrame({'year':all_df_latest['year'].max(),
                        'num_of_bedrooms':beds,
                        'house_value_index':budget,
                        'median_hh_income':income,
                        'poverty_rate':all_df_latest['poverty_rate'].max()},[0])
rfm.predict(rfm_array)
# Out:
# array(['PASSAIC'], dtype=object)

# %%
#  save the model
filename = '../Models/NJ_rfm.sav'
joblib.dump(rfm, filename)
# Out:
# ['../Models/NJ_rfm.sav']

# %% [markdown]
# # Hyper Parameter tuning

# %%
# Create the GridSearchCV model
param_grid = {
    'n_estimators': [200, 600, 1200, 100],
    'max_features': ['sqrt', 'log2'],
    'criterion': ['gini', 'entropy'],
    'max_depth':[None,5,10,15,20]
}
grid = GridSearchCV(rfm, param_grid, cv=3, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV 1/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.851 total time=   0.6s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.854 total time=   0.8s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.832 total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=600;, score=0.851 total time=   1.4s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=600;, score=0.851 total time=   1.8s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=600;, score=0.829 total time=   1.6s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=1200;, score=0.848 total time=   2.9s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=1200;, score=0.854 total time=   2.9s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=1200;, score=0.819 total time=   4.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.841 total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.848 total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.857 total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.844 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.822 total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=600;, score=0.854 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=600;, score=0.851 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=600;, score=0.825 total time=   1.3s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=1200;, score=0.854 total time=   2.7s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=1200;, score=0.857 total time=   2.7s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=1200;, score=0.829 total time=   2.8s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.844 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.622 total time=   0.3s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.641 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.622 total time=   0.3s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=600;, score=0.629 total time=   1.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=600;, score=0.635 total time=   1.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=600;, score=0.629 total time=   1.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=1200;, score=0.635 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=1200;, score=0.651 total time=   2.1s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=1200;, score=0.632 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.648 total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.619 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.638 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.644 total time=   0.3s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.635 total time=   0.3s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200;, score=0.610 total time=   0.3s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=600;, score=0.641 total time=   1.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=600;, score=0.641 total time=   1.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=600;, score=0.622 total time=   1.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=1200;, score=0.635 total time=   2.1s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=1200;, score=0.632 total time=   2.1s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=1200;, score=0.616 total time=   2.1s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.584 total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.632 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.613 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.854 total time=   0.3s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.838 total time=   0.3s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.819 total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=600;, score=0.832 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=600;, score=0.832 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=600;, score=0.800 total time=   1.3s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1200;, score=0.854 total time=   2.6s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1200;, score=0.832 total time=   2.6s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1200;, score=0.800 total time=   2.8s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.819 total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.835 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.816 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.841 total time=   0.3s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.825 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.803 total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=600;, score=0.848 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=600;, score=0.822 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=600;, score=0.803 total time=   1.2s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=1200;, score=0.851 total time=   2.6s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=1200;, score=0.838 total time=   2.5s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=1200;, score=0.806 total time=   2.6s
# [CV 1/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.819 total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.816 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=200;, score=0.851 total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=200;, score=0.835 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=200;, score=0.822 total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=600;, score=0.851 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=600;, score=0.860 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=600;, score=0.822 total time=   1.3s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=1200;, score=0.857 total time=   2.7s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=1200;, score=0.854 total time=   2.6s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=1200;, score=0.822 total time=   2.7s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=100;, score=0.838 total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=sqrt, n_estimators=100;, score=0.813 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=200;, score=0.857 total time=   0.3s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=200;, score=0.851 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=200;, score=0.822 total time=   0.3s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=600;, score=0.854 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=600;, score=0.841 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=600;, score=0.816 total time=   1.3s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=1200;, score=0.854 total time=   2.6s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=1200;, score=0.860 total time=   2.6s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=1200;, score=0.819 total time=   2.6s
# [CV 1/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=15, max_features=log2, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.883 total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.860 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.829 total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=600;, score=0.851 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=600;, score=0.857 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=600;, score=0.825 total time=   1.3s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=1200;, score=0.854 total time=   2.7s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=1200;, score=0.851 total time=   2.6s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=1200;, score=0.822 total time=   2.7s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.851 total time=   0.1s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.803 total time=   0.1s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=200;, score=0.848 total time=   0.4s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=200;, score=0.841 total time=   0.4s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=200;, score=0.819 total time=   0.4s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=600;, score=0.857 total time=   1.3s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=600;, score=0.857 total time=   1.3s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=600;, score=0.832 total time=   1.3s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=1200;, score=0.860 total time=   2.7s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=1200;, score=0.857 total time=   2.8s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=1200;, score=0.816 total time=   2.9s
# [CV 1/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=100;, score=0.848 total time=   0.2s
# [CV 2/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=100;, score=0.844 total time=   0.2s
# [CV 3/3] END criterion=gini, max_depth=20, max_features=log2, n_estimators=100;, score=0.810 total time=   0.1s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.851 total time=   0.5s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.863 total time=   0.5s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.851 total time=   0.6s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=600;, score=0.860 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=600;, score=0.870 total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=600;, score=0.844 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=1200;, score=0.854 total time=   3.9s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=1200;, score=0.844 total time=   4.2s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=1200;, score=0.841 total time=   3.6s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.860 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.870 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.860 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.841 total time=   0.5s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.848 total time=   0.5s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.841 total time=   0.5s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=600;, score=0.857 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=600;, score=0.857 total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=600;, score=0.851 total time=   1.6s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=1200;, score=0.857 total time=   3.5s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=1200;, score=0.854 total time=   3.5s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=1200;, score=0.841 total time=   3.6s
# [CV 1/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.844 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.851 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.857 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.698 total time=   0.4s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.632 total time=   0.4s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.663 total time=   0.4s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=600;, score=0.705 total time=   1.3s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=600;, score=0.660 total time=   1.4s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=600;, score=0.667 total time=   1.3s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1200;, score=0.686 total time=   2.7s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1200;, score=0.654 total time=   3.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1200;, score=0.670 total time=   3.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.663 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.644 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.641 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.689 total time=   0.4s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.657 total time=   0.4s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200;, score=0.654 total time=   0.4s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=600;, score=0.695 total time=   1.3s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=600;, score=0.657 total time=   1.5s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=600;, score=0.657 total time=   1.4s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=1200;, score=0.689 total time=   2.8s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=1200;, score=0.654 total time=   2.8s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=1200;, score=0.670 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.679 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.629 total time=   0.3s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.660 total time=   0.3s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.867 total time=   0.8s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.857 total time=   0.7s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.832 total time=   0.6s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=600;, score=0.844 total time=   2.7s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=600;, score=0.854 total time=   2.1s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=600;, score=0.835 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1200;, score=0.851 total time=   3.9s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1200;, score=0.860 total time=   3.6s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1200;, score=0.841 total time=   5.6s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.844 total time=   0.4s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.848 total time=   0.4s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.841 total time=   0.4s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200;, score=0.857 total time=   0.8s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200;, score=0.860 total time=   0.7s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200;, score=0.844 total time=   0.7s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=600;, score=0.844 total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=600;, score=0.851 total time=   1.7s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=600;, score=0.829 total time=   2.2s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=1200;, score=0.854 total time=   4.0s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=1200;, score=0.854 total time=   3.9s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=1200;, score=0.851 total time=   3.8s
# [CV 1/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.822 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.832 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.835 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=200;, score=0.863 total time=   0.6s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=200;, score=0.876 total time=   0.6s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=200;, score=0.851 total time=   0.6s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=600;, score=0.854 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=600;, score=0.848 total time=   3.9s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=600;, score=0.838 total time=   2.5s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=1200;, score=0.860 total time=   5.5s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=1200;, score=0.860 total time=   5.4s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=1200;, score=0.848 total time=   4.0s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=100;, score=0.835 total time=   0.3s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=100;, score=0.870 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=sqrt, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=200;, score=0.857 total time=   0.7s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=200;, score=0.841 total time=   0.6s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=200;, score=0.838 total time=   0.5s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=600;, score=0.854 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=600;, score=0.848 total time=   2.1s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=600;, score=0.848 total time=   2.2s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=1200;, score=0.844 total time=   5.5s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=1200;, score=0.860 total time=   4.7s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=1200;, score=0.848 total time=   3.9s
# [CV 1/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=100;, score=0.838 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=100;, score=0.832 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=15, max_features=log2, n_estimators=100;, score=0.841 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.848 total time=   0.6s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.854 total time=   0.5s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.841 total time=   0.5s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=600;, score=0.851 total time=   2.2s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=600;, score=0.851 total time=   2.6s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=600;, score=0.848 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=1200;, score=0.857 total time=   4.0s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=1200;, score=0.867 total time=   4.2s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=1200;, score=0.844 total time=   4.4s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.851 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.835 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.832 total time=   0.2s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=200;, score=0.854 total time=   0.6s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=200;, score=0.841 total time=   0.5s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=200;, score=0.832 total time=   0.6s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=600;, score=0.851 total time=   1.7s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=600;, score=0.854 total time=   2.2s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=600;, score=0.844 total time=   2.7s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=1200;, score=0.848 total time=   3.7s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=1200;, score=0.860 total time=   3.9s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=1200;, score=0.841 total time=   3.8s
# [CV 1/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=100;, score=0.835 total time=   0.2s
# [CV 2/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=100;, score=0.857 total time=   0.2s
# [CV 3/3] END criterion=entropy, max_depth=20, max_features=log2, n_estimators=100;, score=0.851 total time=   0.2s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=200),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10, 15, 20],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [200, 600, 1200, 100]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.8634920634920635

# %%
rfm_tuned = RandomForestClassifier(**grid.best_params_)
rfm_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
predictions = rfm_tuned.predict(X_test)
print(f"Training Data Score: {rfm_tuned.score(X_train, y_train)}")
print(f"Testing Data Score: {rfm_tuned.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9333333333333333

# %% [markdown]
# Tuned model has less accuracy so we went with the base model.
