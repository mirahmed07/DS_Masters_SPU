# %%
import pandas as pd

# %%
# import glob
# import os

# %%
# path = os.getcwd()
# ext = '.csv'
# # all_data = [i for i in glob.glob(os.path.join(path, "*.csv"))]
# all_data = [i for i in glob.glob("*.csv")][1:]
# all_data

# %%
# get all the csv filepaths and create a list of files
bikedata_2020_02 = "JC-202002-citibike-tripdata.csv"
bikedata_2020_03 = "JC-202003-citibike-tripdata.csv"
bikedata_2020_04 = "JC-202004-citibike-tripdata.csv"
bikedata_2020_11 = "JC-202011-citibike-tripdata.csv"
bikedata_2020_12 = "JC-202012-citibike-tripdata.csv"


all_files = [bikedata_2020_02, bikedata_2020_03, bikedata_2020_04, bikedata_2020_11, bikedata_2020_12]

# %%
# create empty list to add dataframes to
bikedata_list = []

# for loop to go through each file and read into dataframe, then append to the new list
for file in all_files:
    df = pd.read_csv(file)
    bikedata_list.append(pd.read_csv(file))

# concatenate the list of dataframes to a single dataframe
bikedata_2020 = pd.concat(bikedata_list, sort=False)
bikedata_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1               206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2               859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3               693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4              1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id  start station name  start station latitude  \
# ...

# %%
# export the dataframe to a csv file for using in tableau

bikedata_2020.to_csv("all_bikedata_2020.csv", index=False)
